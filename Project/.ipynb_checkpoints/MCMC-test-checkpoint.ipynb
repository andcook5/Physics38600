# %%
import numpy as np
import matplotlib.pyplot as plt
#%pip install corner
from corner import corner
# Out:
# Collecting corner
#   Downloading corner-2.2.3-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=2.1 in c:\users\andres cook\anaconda3\lib\site-packages (from corner) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andres cook\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\andres cook\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andres cook\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\andres cook\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\andres cook\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\andres cook\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\andres cook\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\andres cook\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andres cook\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\andres cook\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.1->corner) (1.16.0)
# Downloading corner-2.2.3-py3-none-any.whl (15 kB)
# Installing collected packages: corner
# Successfully installed corner-2.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
def fitfun(x, pars):
    tau1_ = pars[0]
    tau2_ = pars[1]
    p_tau1_ = pars[2]

    y = p_tau1_*np.exp(-x/tau1_) + (1 - p_tau1_)*np.exp(-x/tau2_)
    return y

# %%
tau1 = 0.5
tau2 = 4
p_tau1 = 0.5
x = np.linspace(0,5,400)
y = fitfun(x, [tau1, tau2, p_tau1]) + 0.01*np.random.randn(400)
err = np.sqrt(y)
#y /= np.sum(y)
plt.semilogy(x,y,".")
plt.xlabel("delay time [ns]")
plt.ylabel("normalized counts [arb]")
plt.savefig("mix/fitdata.svg")
plt.show()
def log_likelihood(X):
    tau1_ = X[0]
    tau2_ = X[1]
    p_tau1_ = X[2]
    if (tau1_<0) | (tau2_<0) | (tau1_>tau2_) | (abs(p_tau1_ - 0.5)>0.5) | (tau2_>2*np.max(x)):
        return -np.inf
    y_ = fitfun(x,X)
    f = (y - y_)/err
    return np.sum(-f**2)

# %%
init_param_guess = [1,5, 0.3]
num_reps = 100000
jump_mag = [0.2,0.5,0.05]
param_its = np.zeros((len(init_param_guess),num_reps))
param_its[:,0] = init_param_guess
rands = np.random.uniform(0,1,(num_reps))
acceptances = 0
loglikes = np.zeros_like(rands)
for i in range(num_reps-1):
    my_likelihood = log_likelihood(param_its[:,i])
    jump = jump_mag * np.random.randn(np.size(init_param_guess))
    loglikes[i] = my_likelihood
    new_params = param_its[:,i] + jump
    new_likelihood = log_likelihood(new_params)
    if rands[i] <np.exp(new_likelihood - my_likelihood):
        param_its[:,i+1] = new_params
        acceptances += 1
    else:
        param_its[:,i+1] = param_its[:,i]
    plt.plot(x,fitfun(x,param_its[:,i]),'r-', alpha = 0.005*(1+np.tanh(my_likelihood))/2)
plt.plot(x,y,'b--')
plt.xlabel("delay time [ns]")
plt.ylabel("normalized counts [arb]")
plt.title("MCMC results, acceptance rate = {}".format(round(acceptances/num_reps,2)))
plt.savefig("mix/tracks.svg")
plt.show()
print("acceptance rate: {}".format(acceptances/num_reps))
# Out:
# acceptance rate: 0.41508

# %%
plt.plot(np.arange(num_reps),param_its.T,",",label = [r"$\tau_1$", r"$\tau_2$", r"$p_1$"])
plt.plot(np.arange(num_reps),np.tile(np.array([tau1,tau2,p_tau1]),(num_reps,1)),'r--')
plt.xlabel("Iteration number")
plt.ylabel("Parameter value")
plt.legend()
plt.savefig("mix/paramtracks.svg")
plt.show()
cutoff = 200
plt.plot(loglikes[cutoff:])
plt.show()
corner(param_its[:,cutoff:].T,labels = [r"$\tau_1$", r"$\tau_2$", r"$p_1$"],truths = [tau1,tau2,p_tau1])
covar = np.cov(param_its[:,cutoff:])
print(covar)
print(param_its[:,np.argmax(loglikes)])
# Out:
# [[0.08272377 0.29713901 0.02818497]
#  [0.29713901 4.32317454 0.221751  ]
#  [0.02818497 0.221751   0.01675401]]
# [1.32167075 7.82066248 0.75923572]
